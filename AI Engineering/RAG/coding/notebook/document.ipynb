# %% [markdown]
# ### Data Ingestion

# %%
###document data structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="mdojcniken ceiojncdik ceoijdfioc fcaeiofjce",
    metadata={
        "source":"exam",
        "pages":23,
        "author":"Aaditya"
    }
)

doc
# Out:
# Document(metadata={'source': 'exam', 'pages': 23, 'author': 'Aaditya'}, page_content='mdojcniken ceiojncdik ceoijdfioc fcaeiofjce')

# %%
## create a simple txt file


import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":""" 
    Welcome to RAG. 

    Retrieval-Augmented Generation (RAG) is the process of optimizing the output of a large language model, so it references an authoritative knowledge base outside of its training data sources before generating a response. 
    Large Language Models (LLMs) are trained on vast volumes of data and use billions of parameters to generate original output for tasks like answering questions, translating languages, and completing sentences. 
    RAG extends the already powerful capabilities of LLMs to specific domains or an organization's internal knowledge base, all without the need to retrain the model. It is a cost-effective approach to improving LLM output so it remains relevant, accurate, and useful in various contexts.

    """
}


for filepath,content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("Sample text file created")
# Out:
# Sample text file created

# %%
## Textloader



from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()

print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content=" \n    Welcome to RAG. \n\n    Retrieval-Augmented Generation (RAG) is the process of optimizing the output of a large language model, so it references an authoritative knowledge base outside of its training data sources before generating a response. \n    Large Language Models (LLMs) are trained on vast volumes of data and use billions of parameters to generate original output for tasks like answering questions, translating languages, and completing sentences. \n    RAG extends the already powerful capabilities of LLMs to specific domains or an organization's internal knowledge base, all without the need to retrain the model. It is a cost-effective approach to improving LLM output so it remains relevant, accurate, and useful in various contexts.\n\n    ")]

# %%
## PDF Loader

from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls = PyMuPDFLoader,
    show_progress=False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-06-18T17:45:49+00:00', 'source': '..\\data\\pdf\\Aaditya_Padte_Resume (1).pdf', 'file_path': '..\\data\\pdf\\Aaditya_Padte_Resume (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-06-18T17:45:49+00:00', 'trapped': '', 'modDate': 'D:20260618174549Z', 'creationDate': 'D:20260618174549Z', 'page': 0}, page_content='Aaditya Padte\nMumbai, Maharashtra 400025\n\x83 +91 7066022137\n# aadityajp0419@gmail.com ï aaditya-padte-40086a233\n§ Aaditya8C\nEDUCATION\nVeermata Jijabai Technological Institute\nSept 2023 – Aug 2026\nBachelor of Technology in Computer Engineering\nCGPA: 8.7\nGovernment Polytechnic, Mumbai\nSept 2020 – Jun 2023\nDiploma in Computer Engineering\nPercentage: 95.67%\nEXPERIENCE\nContrAll (Construction Site Management Platform)\nMay 2026 – June 2026\nFreelance Full Stack Developer | Flutter, Firebase, Node, AWS, PostgreSql\nMumbai, Maharashtra\n• Engineered a Flutter-based construction management platform for owners and site supervisors, digitizing DPR\nreporting, material tracking, machinery management, and expense workflows across multiple construction sites.\n• Developed a WhatsApp-like communication module with media sharing, entry-linked discussions, unread message\ntracking, and FCM-powered push notifications, improving real-time collaboration between stakeholders.\n• Implemented multilingual support (English, Hindi, Hinglish), reusable component architecture, and advanced filtering\ncapabilities, enhancing usability for field workers and supervisors.\nJPMorgan Chase\nJun 2025 – Aug 2025\nSoftware Engineering Program Intern | React, Spring, Terraform, AWS, Databricks, MySQL\nMumbai, Maharashtra\n• Built a micro-frontend UI from the ground up, integrating it into the broader system architecture and consolidating\nduplicate functionality that was previously scattered across multiple internal projects.\n• Designed and shipped a Spring Boot backend service, enabling seamless communication between the micro-frontend and\nexisting internal APIs within a production-grade ecosystem.\n• Independently deployed the entire service to an AWS ECS cluster using a Jenkins CI/CD pipeline and Terraform for\nInfrastructure as Code (IaC).\nMediSage E-Learning Pvt. Ltd.\nJan 2023 – Jul 2023\nFull Stack Web Developer Intern | Next.js, React.js, VueJs, MySQL, Laravel, Postman, Docker\nMumbai, Maharashtra\n• Re-engineered the search front-end in Next.js for improved accuracy and consistent UI across the platform.\n• Rolled out multi-language support for 2+ languages, expanding platform accessibility to over 10,000 users.\n• Resolved 40% of live bugs within 72 hours in coordination with tech & testing teams.\n• Integrated a suite of medical calculators actively used by 2,000+ healthcare professionals on the platform.\nPROJECTS\nStudyNex: A Virtual Group Study Platform\n| Next.js, Material UI, Socket, Node.js\nJan 2024\n• Built a real-time chat system using WebSockets, supporting text, images, and file sharing via Cloudinary, giving study\ngroups a familiar, low-latency communication experience.\n• Constructed dynamic channel creation feature like discord for the students of the organization.\nTECHNICAL SKILLS\n• Languages: C++, JavaScript, Java, Python, TypeScript, Solidity, SQL\n• Frameworks/Libraries: Next.js, React.js, Node.js, Express.js, Spring, Flutter, React Native, Ethers.js, Laravel\n• Databases: MongoDB, MySQL, MariaDB, Firebase, Oracle SQL, PostgreSql, Databricks\n• Tools & Platforms: Postman, GitHub, Bitbucket, Linux, Figma, Remix, VSCode, Bruno, AWS, Terraform, Jira\nACHIEVEMENTS\n• Invited to Code For Good 2024, a 24-hour hackathon organized by JPMorgan Chase.\n• Won HackXcelerate hackathon in the blockchain track, competing against 20 teams.\n• Conducted Solidity and Git/GitHub workshop for 100+ college students.\n• Designed and deployed competiti ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
